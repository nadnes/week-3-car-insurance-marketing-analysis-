# %%
import pandas as pd
from pandas.api.types import is_numeric_dtype
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file_path = '/Users/nadianesib/Desktop/week3doc/data/data.txt'

# %%
data = pd.read_csv(file_path, sep = "|", low_memory = False)

# %% [markdown]
# Understanding the data

# %%
data #view loaded data
# Out:
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
# ...

# %%
data.head() #the first 5 of the data.NameError: name 'data' is not defined
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
data.tail() #the last 5 line of the data.
# Out:
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
#         Citizenship   LegalType Title Language       Bank      AccountType  \
# 1000093          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000094          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000095          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000096          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000097          ZW  Individual    Mr  English  ABSA Bank  Savings account
#
# ...

# %%
categorical_data = data.select_dtypes(include = ['object','category']).head()

# %%
categorical_data.head()
# Out:
#       TransactionMonth Citizenship          LegalType Title Language  \
# 0  2015-03-01 00:00:00              Close Corporation    Mr  English
# 1  2015-05-01 00:00:00              Close Corporation    Mr  English
# 2  2015-07-01 00:00:00              Close Corporation    Mr  English
# 3  2015-05-01 00:00:00              Close Corporation    Mr  English
# 4  2015-07-01 00:00:00              Close Corporation    Mr  English
#
#                   Bank      AccountType  MaritalStatus         Gender  \
# 0  First National Bank  Current account  Not specified  Not specified
# 1  First National Bank  Current account  Not specified  Not specified
# 2  First National Bank  Current account  Not specified  Not specified
# 3  First National Bank  Current account  Not specified  Not specified
# 4  First National Bank  Current account  Not specified  Not specified
#
#         Country  ... CrossBorder TermFrequency  \
# 0  South Africa  ...         NaN       Monthly
# ...

# %%
numerical_data = data.select_dtypes(include = ['int','float']).head()

# %%
numerical_data.head()
# Out:
#    UnderwrittenCoverID  PolicyID  PostalCode      mmcode  RegistrationYear  \
# 0               145249     12827        1459  44069150.0              2004
# 1               145249     12827        1459  44069150.0              2004
# 2               145249     12827        1459  44069150.0              2004
# 3               145255     12827        1459  44069150.0              2004
# 4               145255     12827        1459  44069150.0              2004
#
#    Cylinders  cubiccapacity  kilowatts  NumberOfDoors  CustomValueEstimate  \
# 0        6.0         2597.0      130.0            4.0             119300.0
# 1        6.0         2597.0      130.0            4.0             119300.0
# 2        6.0         2597.0      130.0            4.0             119300.0
# 3        6.0         2597.0      130.0            4.0             119300.0
# 4        6.0         2597.0      130.0            4.0             119300.0
#
# ...

# %%
data.shape # total rows and columns of the data
# Out:
# (1000098, 52)

# %%
data.describe() #Summary statistics of the Series or Dataframe provided.
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %%
data.count #Count number of non-NA/null observations.
# Out:
# <bound method DataFrame.count of          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
# ...

# %%
data.max #Return the maximum of the values
# Out:
# <bound method DataFrame.max of          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
# ...

# %%
data.min #Return the minimum of the values
# Out:
# <bound method DataFrame.min of          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
# ...

# %%
data.std #Standard deviation of the observations.
# Out:
# <bound method DataFrame.std of          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
# ...

# %%
data.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
data.nunique() #searches for a unique value in our data
# Out:
# UnderwrittenCoverID         116532
# PolicyID                      7000
# TransactionMonth                23
# IsVATRegistered                  2
# Citizenship                      4
# LegalType                        6
# Title                            5
# Language                         1
# Bank                            11
# AccountType                      3
# MaritalStatus                    3
# Gender                           3
# Country                          1
# Province                         9
# PostalCode                     888
# MainCrestaZone                  16
# SubCrestaZone                   45
# ItemType                         1
# mmcode                         427
# VehicleType                      5
# RegistrationYear                25
# make                            46
# Model                          411
# Cylinders                        7
# cubiccapacity                  122
# kilowatts                       82
# bodytype                        13
# ...

# %%
data.mean #Mean of the values.
# Out:
# <bound method DataFrame.mean of          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
# ...

# %%
data['VehicleType'].unique()
# Out:
# array(['Passenger Vehicle', 'Medium Commercial', 'Heavy Commercial',
#        'Light Commercial', 'Bus', nan], dtype=object)

# %%
data['TotalPremium'].unique()
# Out:
# array([ 21.92982456,   0.        , 512.84807018, ...,  69.524618  ,
#          2.43267402, 182.44917657])

# %%
data['Gender'].unique()
# Out:
# array(['Not specified', 'Male', 'Female', nan], dtype=object)

# %% [markdown]
# #cleaning data

# %%
data.isnull().sum()
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %% [markdown]
#      Data summarization (automatically computesbasic statistics for all continuous variables(floats and integer                 data types and skip NAN's and show that count of variable mean,std,min,max&IQR) )

# %%
#descriptive statistics( Calculate the variability for numerical features such as TotalPremium, TotalClaim)

# %%
data.describe()
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %%
#value_counts() applies on panda series, so use single bracket.
data['TotalPremium'].value_counts()
# Out:
# TotalPremium
# 0.000000      381634
# 21.929825      49731
# 74.561404      34382
# 78.947368      30400
# 43.859649      16919
#                ...
# 225.441504         1
# 77.661128          1
# 62.791867          1
# 639.442632         1
# 182.449177         1
# Name: count, Length: 38959, dtype: int64

# %%
data['TotalPremium'].value_counts().to_frame()
# Out:
#                count
# TotalPremium
# 0.000000      381634
# 21.929825      49731
# 74.561404      34382
# 78.947368      30400
# 43.859649      16919
# ...              ...
# 225.441504         1
# 77.661128          1
# 62.791867          1
# 639.442632         1
# 182.449177         1
#
# [38959 rows x 1 columns]

# %%
data['TotalClaims'].value_counts()
# Out:
# TotalClaims
# 0.000000        997305
# 6140.350877        326
# 750.649123         101
# 1300.000000         59
# 850.000000          51
#                  ...
# 17239.394737         1
# 36251.938596         1
# 54631.578947         1
# 1622.807018          1
# 28903.850877         1
# Name: count, Length: 1615, dtype: int64

# %%
data['TotalPremium'].value_counts().to_frame()
# Out:
#                count
# TotalPremium
# 0.000000      381634
# 21.929825      49731
# 74.561404      34382
# 78.947368      30400
# 43.859649      16919
# ...              ...
# 225.441504         1
# 77.661128          1
# 62.791867          1
# 639.442632         1
# 182.449177         1
#
# [38959 rows x 1 columns]

# %%
data['RegistrationYear'].value_counts()
# Out:
# RegistrationYear
# 2014    155889
# 2012    130884
# 2013    117064
# 2008    106008
# 2010     95579
# 2011     88765
# 2007     82514
# 2009     72168
# 2006     45111
# 2005     30901
# 2015     27589
# 2004     16956
# 2003     10756
# 2002      6574
# 2001      5858
# 1999      1862
# 2000      1740
# 1998      1465
# 1997      1045
# 1996       867
# 1995       446
# 1994        52
# 1987         3
# 1992         1
# 1988         1
# Name: count, dtype: int64

# %%
data['CalculatedPremiumPerTerm'].value_counts()
# Out:
# CalculatedPremiumPerTerm
# 25.0000      81499
# 85.0000      59987
# 90.0000      53581
# 50.0000      27508
# 18.0000      25188
#              ...
# 1160.8258        1
# 247.7150         1
# 163.5827         1
# 379.7715         1
# 552.8689         1
# Name: count, Length: 19869, dtype: int64

# %%
data['CalculatedPremiumPerTerm'].value_counts().to_frame()
# Out:
#                           count
# CalculatedPremiumPerTerm
# 25.0000                   81499
# 85.0000                   59987
# 90.0000                   53581
# 50.0000                   27508
# 18.0000                   25188
# ...                         ...
# 1160.8258                     1
# 247.7150                      1
# 163.5827                      1
# 379.7715                      1
# 552.8689                      1
#
# [19869 rows x 1 columns]

# %%
data['PolicyID'].value_counts()
# Out:
# PolicyID
# 3870     10400
# 698       4500
# 5351      3080
# 6924      2852
# 9774      2392
#          ...
# 10900        1
# 20825        1
# 12879        1
# 11042        1
# 22854        1
# Name: count, Length: 7000, dtype: int64

# %%
data['PolicyID'].value_counts().to_frame()
# Out:
#           count
# PolicyID
# 3870      10400
# 698        4500
# 5351       3080
# 6924       2852
# 9774       2392
# ...         ...
# 10900         1
# 20825         1
# 12879         1
# 11042         1
# 22854         1
#
# [7000 rows x 1 columns]

# %% [markdown]
# Data Structure

# %%
# Review the dtype of each column to confirm if categorical variables, dates, etc. are properly formatted.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...

# %%
data.dtypes
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %%
data['AlarmImmobiliser']
# Out:
# 0          Yes
# 1          Yes
# 2          Yes
# 3          Yes
# 4          Yes
#           ...
# 1000093    Yes
# 1000094    Yes
# 1000095    Yes
# 1000096    Yes
# 1000097    Yes
# Name: AlarmImmobiliser, Length: 1000098, dtype: object

# %%
data['Bank']
# Out:
# 0          First National Bank
# 1          First National Bank
# 2          First National Bank
# 3          First National Bank
# 4          First National Bank
#                   ...
# 1000093              ABSA Bank
# 1000094              ABSA Bank
# 1000095              ABSA Bank
# 1000096              ABSA Bank
# 1000097              ABSA Bank
# Name: Bank, Length: 1000098, dtype: object

# %%
data['TrackingDevice']
# Out:
# 0          No
# 1          No
# 2          No
# 3          No
# 4          No
#            ..
# 1000093    No
# 1000094    No
# 1000095    No
# 1000096    No
# 1000097    No
# Name: TrackingDevice, Length: 1000098, dtype: object

# %%
data['Cylinders']
# Out:
# 0          6.0
# 1          6.0
# 2          6.0
# 3          6.0
# 4          6.0
#           ...
# 1000093    4.0
# 1000094    4.0
# 1000095    4.0
# 1000096    4.0
# 1000097    4.0
# Name: Cylinders, Length: 1000098, dtype: float64

# %%
is_numeric_dtype(data['Product'])
# Out:
# False

# %% [markdown]
#                        Data Quality Assessment:

# %%
#Check for missing values.

# %%
data.isnull()
# Out:
#          UnderwrittenCoverID  PolicyID  TransactionMonth  IsVATRegistered  \
# 0                      False     False             False            False
# 1                      False     False             False            False
# 2                      False     False             False            False
# 3                      False     False             False            False
# 4                      False     False             False            False
# ...                      ...       ...               ...              ...
# 1000093                False     False             False            False
# 1000094                False     False             False            False
# 1000095                False     False             False            False
# 1000096                False     False             False            False
# 1000097                False     False             False            False
#
#          Citizenship  LegalType  Title  Language   Bank  AccountType  ...  \
# ...

# %%
data.isnull().sum()
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %%
data.isnull().sum().sum()
# Out:
# 5067648

# %% [markdown]
#             Filling the null values.

# %%
data2 = data.fillna(value = 0)
data2
# Out:
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
# ...

# %%
data2.isnull().sum().sum()
# Out:
# 0

# %%
#we can also replace a null value with whatever we want and even with a previous value without affecting the original value

# %% [markdown]
#                           Univariate Analysis

# %%
#Distribution of Variables 
    
#Plot histograms for numerical columns.

# %%
data.hist(column = 'UnderwrittenCoverID')
# Out:
# array([[<Axes: title={'center': 'UnderwrittenCoverID'}>]], dtype=object)

# %%
data.hist(column = 'PolicyID')
# Out:
# array([[<Axes: title={'center': 'PolicyID'}>]], dtype=object)

# %%
data.hist(column = 'PostalCode')
# Out:
# array([[<Axes: title={'center': 'PostalCode'}>]], dtype=object)

# %%
data.hist(column = 'mmcode')
# Out:
# array([[<Axes: title={'center': 'mmcode'}>]], dtype=object)

# %%
data.hist(column = 'RegistrationYear')
# Out:
# array([[<Axes: title={'center': 'RegistrationYear'}>]], dtype=object)

# %%
data.hist(column = 'Cylinders')
# Out:
# array([[<Axes: title={'center': 'Cylinders'}>]], dtype=object)

# %%
data.hist(column = 'cubiccapacity')
# Out:
# array([[<Axes: title={'center': 'cubiccapacity'}>]], dtype=object)

# %%
data.hist(column = 'kilowatts')
# Out:
# array([[<Axes: title={'center': 'kilowatts'}>]], dtype=object)

# %%
data.hist(column = 'NumberOfDoors')
# Out:
# array([[<Axes: title={'center': 'NumberOfDoors'}>]], dtype=object)

# %%
data.hist(column = 'CustomValueEstimate')
# Out:
# array([[<Axes: title={'center': 'CustomValueEstimate'}>]], dtype=object)

# %%
data.hist(column = 'NumberOfVehiclesInFleet')
# Out:
# array([[<Axes: title={'center': 'NumberOfVehiclesInFleet'}>]],
#       dtype=object)

# %%
data.hist(column = 'SumInsured')
# Out:
# array([[<Axes: title={'center': 'SumInsured'}>]], dtype=object)

# %%
data.hist(column = 'CalculatedPremiumPerTerm')
# Out:
# array([[<Axes: title={'center': 'CalculatedPremiumPerTerm'}>]],
#       dtype=object)

# %%
data.hist(column = 'TotalPremium')
# Out:
# array([[<Axes: title={'center': 'TotalPremium'}>]], dtype=object)

# %%
data.hist(column = 'TotalClaims')
# Out:
# array([[<Axes: title={'center': 'TotalClaims'}>]], dtype=object)

# %%
#bar charts for categorical columns to understand distributions..

# %%
data.head()
# Out:
#    UnderwrittenCoverID  PolicyID   TransactionMonth  IsVATRegistered  \
# 0               145249     12827  20150301 00:00:00             True
# 1               145249     12827  20150501 00:00:00             True
# 2               145249     12827  20150701 00:00:00             True
# 3               145255     12827  20150501 00:00:00             True
# 4               145255     12827  20150701 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %% [markdown]
#                           Bivariate or Multivariate Analysis

# %%
#Correlations and Associations meaning

# %% [markdown]
#                  Outliers

# %%
#(are data points that differs significantly from other observation in statistics. due to variability in measurement or indicate experimental error the latter can be excluded from the data set cause it can cause a series of problemm in the data set.)

# %%
#Correlations and Associations: Explore relationships between the monthly changes TotalPremium and TotalClaims as a function of ZipCode, using scatter plots and correlation matrices.

# %%
#relationship anlysis

# %%
#correlation matrix(gives us a wider "x" perspective on what are we dealing with or a table showing corelation coefficient b/n variables also used in summarization of data as an input diagnostic to advanced analysis each cell in the table shows correlation b/n two variables.)
